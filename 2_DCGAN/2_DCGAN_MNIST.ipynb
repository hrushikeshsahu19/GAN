# %%
from tensorflow.keras.datasets.mnist import load_data

# %%
(X_train, _),(_, _) = load_data()

# %%
print("Data shape:", X_train.shape)
# Out:
# Data shape: (60000, 28, 28)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.axis("off")
    plt.imshow(X_train[i], cmap="gray_r")
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, LeakyReLU, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
def define_discriminator(input_shape=(28,28,1)):
    model = Sequential()
    model.add(Conv2D(64, kernel_size=(3,3), strides=(2,2), padding="same", input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    model.add(Conv2D(64, kernel_size=(3,3), strides=(2,2), padding="same"))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(1, activation="sigmoid"))
    
    optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
    
    model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    return model

# %%
import numpy as np

# %%
X = np.expand_dims(X_train, -1)

# %%
X.astype("float32")
X = X/127.5 - 1

# %%
def generate_real_samples(dataset, n_samples):
    ix = np.random.randint(0, dataset.shape[0], n_samples)
    X = dataset[ix]
    y = 0.7 + (np.random.random(n_samples) * 0.5)
    return X, y.reshape((n_samples, 1))

# %%
from tensorflow.keras.layers import Conv2DTranspose, Reshape
def define_generator(latent_dim):
    model = Sequential()
    model.add(Dense(128*7*7, input_dim = latent_dim))
    model.add(LeakyReLU(0.2))
    model.add(Reshape((7,7,128)))
    model.add(Conv2DTranspose(128, kernel_size=(4,4), strides=(2,2), padding="same"))
    model.add(BatchNormalization())
    model.add(LeakyReLU(0.2))
    model.add(Conv2DTranspose(128, kernel_size=(4,4), strides=(2,2), padding="same"))
    model.add(BatchNormalization())
    model.add(LeakyReLU(0.2))
    model.add(Conv2D(1, kernel_size=(7,7), activation="tanh", padding="same"))
    
    model.summary()
    return model

# %%
def generate_latent_points(latent_dim, n_samples):
    X_input = np.random.randn(latent_dim*n_samples)
    X_input = X_input.reshape((n_samples, latent_dim))
    return X_input

# %%
def generate_fake_samples(generator, latent_dim, n_samples):
    X_input = generate_latent_points(latent_dim, n_samples)
    X = generator.predict(X_input)
    y = np.random.random(n_samples) * 0.3
    return X, y.reshape((n_samples, 1))

# %%
generator = define_generator(100)
X_fake_samples, _ = generate_fake_samples(generator, 100, 25)
plt.figure(figsize=(8,6))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.axis("off")
    plt.imshow(X_fake_samples[i,:,:,0], cmap="gray_r")
plt.savefig("mnist_gen/Epoch_0.png")
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6272)              633472
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 128)       262272
# _________________________________________________________________
# batch_normalization (BatchNo (None, 14, 14, 128)       512
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 128)       262272
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 1)         6273
# =================================================================
# Total params: 1,165,313
# Trainable params: 1,164,801
# Non-trainable params: 512
# _________________________________________________________________

# %%
def define_gan(generator, discriminator):
    discriminator.trainable = False
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(optimizer=optimizer, loss="binary_crossentropy")
    model.summary()
    return model

# %%
def hard_y(y):
  for i in range(len(y)):
    if y[i] <= 0.3:
      y[i] = 0
    else:
      y[i] = 1
  return y

# %%
from IPython.display import clear_output
def summarize_performance(epoch, generator, discriminator, dataset, latent_dim, n=100):
    clear_output()
    X_real, y_real = generate_real_samples(dataset, n)
    X_fake, y_fake = generate_fake_samples(generator, latent_dim, n)
    y_real = hard_y(y_real)
    y_fake = hard_y(y_fake)
    plt.figure(figsize=(10,8))
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.axis("off")
        plt.imshow(X_fake[i,:,:,0], cmap="gray_r")
    plt.savefig("mnist_gen/Epoch_"+str(epoch+1)+".png")
    plt.show()
    _, acc_real = discriminator.evaluate(X_real, y_real, verbose=0)
    _, acc_fake = discriminator.evaluate(X_fake, y_fake, verbose=0)
    print("\nEpoch %4d => Real Accuracy = %.3f, Fake Accuracy = %.3f"%(epoch+1,acc_real,acc_fake))

# %%
from tqdm import tqdm
def train(generator, discriminator, gan, dataset, latent_dim, n_epochs=100, n_batch=256):
    batch_per_epoch = dataset.shape[0]//n_batch
    half_batch = n_batch//2
    for i in range(n_epochs):
        d_loss = gan_loss = 0
        for j in tqdm(range(batch_per_epoch)):
            X_real, y_real = generate_real_samples(dataset, half_batch)
            X_fake, y_fake = generate_fake_samples(generator, latent_dim, half_batch)
            X, y = np.vstack((X_real, X_fake)), np.vstack((y_real, y_fake))
            d_loss, _ = discriminator.train_on_batch(X, y)
            X_gan = generate_latent_points(latent_dim, n_batch)
            y_gan = 0.7 + (np.random.random(n_batch) * 0.5)
            y_gan = y_gan.reshape((n_batch, 1))
            gan_loss = gan.train_on_batch(X_gan, y_gan)
        summarize_performance(i, generator, discriminator, dataset, latent_dim)
        print("\nDiscriminator Loss: %.3f, GAN Loss: %.3f"%(d_loss, gan_loss))

# %%
latent_dim = 50

# %%
generator = define_generator(latent_dim)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 6272)              319872
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 6272)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 14, 14, 128)       262272
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 128)       262272
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 1)         6273
# =================================================================
# Total params: 851,713
# Trainable params: 851,201
# Non-trainable params: 512
# _________________________________________________________________

# %%
discriminator = define_discriminator()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 3137
# =================================================================
# Total params: 41,217
# Trainable params: 40,961
# Non-trainable params: 256
# _________________________________________________________________

# %%
model = define_gan(generator, discriminator)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_1 (Sequential)    (None, 28, 28, 1)         851713
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 1)                 41217
# =================================================================
# Total params: 892,930
# Trainable params: 851,201
# Non-trainable params: 41,729
# _________________________________________________________________

# %%
train(generator, discriminator, model, X, latent_dim, n_epochs=200)
# Out:
#   0%|                                                                                                                                                                                     | 0/234 [00:00<?, ?it/s]
# Epoch    1 => Real Accuracy = 1.000, Fake Accuracy = 0.000
#
# Discriminator Loss: 0.324, GAN Loss: 0.223
#  58%|██████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                        | 135/234 [00:48<00:35,  2.81it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-ad8a637af1bd> in <module>
# ----> 1 train(generator, discriminator, model, X, latent_dim, n_epochs=200)
#
# <ipython-input-19-0e2a8ac48469> in train(generator, discriminator, gan, dataset, latent_dim, n_epochs, n_batch)
#      13             y_gan = 0.7 + (np.random.random(n_batch) * 0.5)
#      14             y_gan = y_gan.reshape((n_batch, 1))
# ---> 15             gan_loss = gan.train_on_batch(X_gan, y_gan)
#      16         summarize_performance(i, generator, discriminator, dataset, latent_dim)
#      17         print("\nDiscriminator Loss: %.3f, GAN Loss: %.3f"%(d_loss, gan_loss))
#
# d:\python\env_ml\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1696
#    1697     if reset_metrics:
# -> 1698       self.reset_metrics()
#    1699     logs = tf_utils.to_numpy_or_python_type(logs)
#    1700     if return_dict:
#
# d:\python\env_ml\lib\site-packages\tensorflow\python\keras\engine\training.py in reset_metrics(self)
#    1635     """
#    1636     for m in self.metrics:
# -> 1637       m.reset_states()
#    1638
#    1639   def train_on_batch(self,
#
# d:\python\env_ml\lib\site-packages\tensorflow\python\keras\metrics.py in reset_states(self)
#     245     when a metric is evaluated during training.
#     246     """
# --> 247     K.batch_set_value([(v, 0) for v in self.variables])
#     248
#     249   @abc.abstractmethod
#
# d:\python\env_ml\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# d:\python\env_ml\lib\site-packages\tensorflow\python\keras\backend.py in batch_set_value(tuples)
#    3574   if ops.executing_eagerly_outside_functions():
#    3575     for x, value in tuples:
# -> 3576       x.assign(np.asarray(value, dtype=dtype(x)))
#    3577   else:
#    3578     with get_graph().as_default():
#
# d:\python\env_ml\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     857       value_tensor = ops.convert_to_tensor(value, dtype=self.dtype)
#     858       self._shape.assert_is_compatible_with(value_tensor.shape)
# --> 859       assign_op = gen_resource_variable_ops.assign_variable_op(
#     860           self.handle, value_tensor, name=name)
#     861       if read_value:
#
# d:\python\env_ml\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py in assign_variable_op(resource, value, name)
#     140   if tld.is_eager:
#     141     try:
# --> 142       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     143         _ctx._context_handle, tld.device_name, "AssignVariableOp", name,
#     144         tld.op_callbacks, resource, value)
#
# KeyboardInterrupt:

# %%
from tqdm import tqdm
plt.figure(figsize=(20, 20))
for i in tqdm(range(100)):
  plt.subplot(10,10,i+1)
  plt.axis("off")
  predict = generator.predict(np.random.random((1,latent_dim))*2-1)
  plt.imshow(predict[0,:,:,0], cmap="gray_r")
plt.savefig("mnist_gen/final.png")
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 24.29it/s]
